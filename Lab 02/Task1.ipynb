# %% [markdown]
# **Task 01**
#
# *1. Download any dataset of your own choice having numerical and categorical data. Find out the basic
# data understanding information such as few of the random rows, shape of the dataset, information
# of the variables, either any empty or null row exist or not*

# %%
# Import Pandas, Seaborn and Matplotlib

import pandas as pd
import seaborn as sns  
import matplotlib.pyplot as plt

# %%
# Load the Dataset

df = pd.read_csv("D:\\1. Academics\\7th Semester Stuff\\Data Analytics Lab\\Lab 02\\Titanic-Dataset.csv")

df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 797          798         1       3
# 252          253         0       1
# 307          308         1       1
# 152          153         0       3
# 373          374         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 797                                   Osman, Mrs. Mara  female  31.0      0
# 252                          Stead, Mr. William Thomas    male  62.0      0
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 373                                Ringhini, Mr. Sante    male  22.0      0
#
#      Parch      Ticket      Fare Cabin Embarked
# 797      0      349244    8.6833   NaN        S
# 252      0      113514   26.5500   C87        S
# 307      0    PC 17758  108.9000   C65        C
# 152      0  A.5. 11206    8.0500   NaN        S
# 373      0    PC 17760  135.6333   NaN        C

# %%
# Print the Shape of the Dataset

print("Shape of the Dataset: ",df.shape)
# Out:
# Shape of the Dataset:  (891, 12)

# %%
# Information of the Dataset

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
# Displat the Number of NULL Values in each Feature

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
