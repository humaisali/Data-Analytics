# %% [markdown]
# **Task 04**
#
# *4. Pandas Profiling is a python library that provides detail report about the variable of the dataset. Apply pandas profiling on any of the dataset and clearly mention the report in the form of screenshots as well.*

# %%
import pandas as pd
from data_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 from data_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'data_profiling'

# %%
# Read the Titanic Dataset

df = pd.read_csv("Titanic_Dataset.csv")

# Generate the Profiling Report

profile = ProfileReport(
    df,
    title="Titanic Dataset Profiling Report"
)

# Display the Profiling Report

profile.to_notebook_iframe()

profile.to_file("Titanic_Profiling_Report.html")
