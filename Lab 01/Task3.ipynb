# %% [markdown]
# **Task 03**

# %% [markdown]
# *Download the dataset of your own choice and display its random data (5 rows), basic information of the dataset and shape of the dataset using pandas built-in function.*

# %%
import pandas as pd

df = pd.read_csv("D:\\1. Academics\\7th Semester Stuff\\Data Analysis Lab\\Lab 01\\Titanic-Dataset.csv")

# Dispaly Random 5 Rows from the Dataset

df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 502          503         0       3  O'Sullivan, Miss. Bridget Mary  female
# 2              3         1       3          Heikkinen, Miss. Laina  female
# 155          156         0       1     Williams, Mr. Charles Duane    male
# 825          826         0       3                 Flynn, Mr. John    male
# 274          275         1       3      Healy, Miss. Hanora "Nora"  female
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 502   NaN      0      0            330909   7.6292   NaN        Q
# 2    26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 155  51.0      0      1          PC 17597  61.3792   NaN        C
# 825   NaN      0      0            368323   6.9500   NaN        Q
# 274   NaN      0      0            370375   7.7500   NaN        Q

# %% [markdown]
# *Also display last five rows of the dataset using pandas function*

# %%
# Dispaly the Last 5 Rows from the Dataset

df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# *Display the whole information of the dataset*

# %%
# Display the whole information of the dataset

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# *Display the shape of the dataset that is number of rows and columns*

# %%
# Display the shape of the dataset that is number of rows and columns

df.shape
# Out:
# (891, 12)
