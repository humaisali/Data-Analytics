# %% [markdown]
# *One of the technique for imputing/filling the numerical univariate is to impute them with the Mean of the column. When the data is normal distributed, the imputation with the mean is the best approach, however, the variance will be shrink with the mean imputation. Apply this approach on numerical column and compare the variance before and after applying mean.*

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Building_Permits.csv")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7880\1014540178.py:1: DtypeWarning: Columns (0: Voluntary Soft-Story Retrofit, 1: TIDF Compliance) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Building_Permits.csv")

# %%
df["Estimated Cost"].skew()
# Out:
# np.float64(80.26767045303886)

# %%
# lets impute the missing value to make a new df
new_df = df["Estimated Cost"].fillna(df['Estimated Cost' ].mean())

# %%
# Now calculate the varience of both the frames
print("Varience before imputing the missing values", df['Estimated Cost'].var())
# Out:
# Varience before imputing the missing values 13179702172618.324
